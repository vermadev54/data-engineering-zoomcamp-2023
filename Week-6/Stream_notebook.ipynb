# %%
import os
os.environ['PYSPARK_SUBMIT_ARGS'] = '--packages org.apache.spark:spark-sql-kafka-0-10_2.12:3.3.1,org.apache.spark:spark-avro_2.12:3.3.1 pyspark-shell'

# %%
from pyspark.sql import SparkSession
import pyspark.sql.types as T
import pyspark.sql.functions as F
from pyspark.sql.functions import sum, col, desc



spark = SparkSession \
    .builder \
    .appName("Spark-Notebook") \
    .getOrCreate()
spark.sparkContext.setLogLevel('WARN')
# Out:
# :: loading settings :: url = jar:file:/home/jainendra/spark/spark-3.3.2-bin-hadoop3/jars/ivy-2.5.1.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /home/jainendra/.ivy2/cache
# The jars for the packages stored in: /home/jainendra/.ivy2/jars
# org.apache.spark#spark-sql-kafka-0-10_2.12 added as a dependency
# org.apache.spark#spark-avro_2.12 added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-5f8be0c4-f3b4-4aef-ba48-e0856aeb1834;1.0
# 	confs: [default]
# 	found org.apache.spark#spark-sql-kafka-0-10_2.12;3.3.1 in central
# 	found org.apache.spark#spark-token-provider-kafka-0-10_2.12;3.3.1 in central
# 	found org.apache.kafka#kafka-clients;2.8.1 in central
# 	found org.lz4#lz4-java;1.8.0 in central
# 	found org.xerial.snappy#snappy-java;1.1.8.4 in central
# 	found org.slf4j#slf4j-api;1.7.32 in central
# 	found org.apache.hadoop#hadoop-client-runtime;3.3.2 in central
# 	found org.spark-project.spark#unused;1.0.0 in central
# 	found org.apache.hadoop#hadoop-client-api;3.3.2 in central
# 	found commons-logging#commons-logging;1.1.3 in central
# 	found com.google.code.findbugs#jsr305;3.0.0 in central
# 	found org.apache.commons#commons-pool2;2.11.1 in central
# 	found org.apache.spark#spark-avro_2.12;3.3.1 in central
# 	found org.tukaani#xz;1.8 in central
# :: resolution report :: resolve 870ms :: artifacts dl 28ms
# 	:: modules in use:
# 	com.google.code.findbugs#jsr305;3.0.0 from central in [default]
# 	commons-logging#commons-logging;1.1.3 from central in [default]
# 	org.apache.commons#commons-pool2;2.11.1 from central in [default]
# 	org.apache.hadoop#hadoop-client-api;3.3.2 from central in [default]
# 	org.apache.hadoop#hadoop-client-runtime;3.3.2 from central in [default]
# 	org.apache.kafka#kafka-clients;2.8.1 from central in [default]
# 	org.apache.spark#spark-avro_2.12;3.3.1 from central in [default]
# 	org.apache.spark#spark-sql-kafka-0-10_2.12;3.3.1 from central in [default]
# 	org.apache.spark#spark-token-provider-kafka-0-10_2.12;3.3.1 from central in [default]
# 	org.lz4#lz4-java;1.8.0 from central in [default]
# 	org.slf4j#slf4j-api;1.7.32 from central in [default]
# 	org.spark-project.spark#unused;1.0.0 from central in [default]
# 	org.tukaani#xz;1.8 from central in [default]
# 	org.xerial.snappy#snappy-java;1.1.8.4 from central in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |   14  |   0   |   0   |   0   ||   14  |   0   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-5f8be0c4-f3b4-4aef-ba48-e0856aeb1834
# 	confs: [default]
# 	0 artifacts copied, 14 already retrieved (0kB/16ms)
# 23/03/14 11:30:36 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).

# %%
df_kafka_raw = spark \
      .readStream \
      .format("kafka") \
      .option("kafka.bootstrap.servers", "*************") \
      .option("subscribe", "rides_green,rides_fhv") \
      .option("startingOffsets", "earliest") \
      .option("kafka.security.protocol","SASL_SSL") \
      .option("kafka.sasl.mechanism", "PLAIN") \
      .option("kafka.sasl.jaas.config",
        """org.apache.kafka.common.security.plain.PlainLoginModule required username="************" password="************";""").load()

# %%
df_kafka_raw.printSchema()
# Out:
# root
#  |-- key: binary (nullable = true)
#  |-- value: binary (nullable = true)
#  |-- topic: string (nullable = true)
#  |-- partition: integer (nullable = true)
#  |-- offset: long (nullable = true)
#  |-- timestamp: timestamp (nullable = true)
#  |-- timestampType: integer (nullable = true)

# %%
df_kafka_raw
# Out:
# DataFrame[key: binary, value: binary, topic: string, partition: int, offset: bigint, timestamp: timestamp, timestampType: int]

# %%
df_kafka_encoded = df_kafka_raw.selectExpr("CAST(key AS STRING)","CAST(value AS STRING)")

# %%
df_kafka_encoded.printSchema()
# Out:
# root
#  |-- key: string (nullable = true)
#  |-- value: string (nullable = true)

# %%
def parse_ride_from_kafka_message(df_raw, schema):
    """ take a Spark Streaming df and parse value col based on <schema>, return streaming df cols in schema """
    assert df_raw.isStreaming is True, "DataFrame doesn't receive streaming data"

    df = df_raw.selectExpr("CAST(key AS STRING)", "CAST(value AS STRING)")

    # split attributes to nested array in one Column

    col = F.split(df['value'], ', ')
    #print(col)

    # expand col to multiple top-level columns
    for idx, field in enumerate(schema):
        #print (field.name,col.getItem(idx).cast(field.dataType) )
        df = df.withColumn(field.name, col.getItem(idx).cast(field.dataType))
    return df.select([field.name for field in schema])

# %%
#         self.dispatching_base_num = arr[1]
#         self.pickup_datetime = datetime.strptime(arr[2], "%Y-%m-%d %H:%M:%S"),
#         self.dropOff_datetime = datetime.strptime(arr[3], "%Y-%m-%d %H:%M:%S"),
#         self.PULocationID = int(eval(arr[4]))
#         self.DOLocationID = int(eval(arr[5]))
#         self.SR_Flag = arr[6]
#         self.Affiliated_base_number = arr[7]

ride_schema = T.StructType(
    [#T.StructField("dispatching_base_num", T.StringType()),
     T.StructField('pickup_datetime', T.StringType()),
     T.StructField('dropOff_datetime', T.StringType()),
     T.StructField("PULocationID", T.StringType()),
     T.StructField("DOLocationID", T.StringType()),
     #T.StructField("SR_Flag", T.StringType()),
     #T.StructField("Affiliated_base_number", T.StringType()),
     T.StructField("texi_type", T.StringType())
     ])

# %%
df_rides = parse_ride_from_kafka_message(df_raw=df_kafka_raw, schema=ride_schema)

# %%
df_rides.printSchema()

# %%
def sink_console(df, output_mode: str = 'complete', processing_time: str = '5 seconds'):
    write_query = df.writeStream \
        .outputMode(output_mode) \
        .trigger(processingTime=processing_time) \
        .format("console") \
        .option("truncate", False) \
        .start()
    return write_query # pyspark.sql.streaming.StreamingQuery

# %%
write_query = sink_console(df_rides, output_mode='append')

# %%
def sink_memory(df, query_name, query_template):
    write_query = df \
        .writeStream \
        .queryName(query_name) \
        .format('memory') \
        .start()
    query_str = query_template.format(table_name=query_name)
    query_results = spark.sql(query_str)
    return write_query, query_results

# %%
query_name = 'frequent_pipup_location'
query_template = 'select count(distinct(PULocationID)) from {table_name}'
write_query, df_vendor_location_id = sink_memory(df=df_rides, query_name=query_name, query_template=query_template)

# %%
print(type(write_query)) # pyspark.sql.streaming.StreamingQuery
write_query.status

# %%
df_vendor_location_id.show()

# %%
#'pickup_datetime','dropOff_datetime','PULocationID','DOLocationID','texi_type'
    
df_trip_messages = prepare_dataframe_to_kafka_sink(df=df_rides,
                                                  value_columns=["texi_type"], key_column='PULocationID')
kafka_sink_query = sink_kafka(df=df_trip_messages, topic="rides_all")

# %%
def sink_console(df, output_mode: str = 'complete', processing_time: str = '5 seconds'):
    write_query = df.writeStream \
        .outputMode(output_mode) \
        .trigger(processingTime=processing_time) \
        .format("console") \
        .option("truncate", False) \
        .start()
    return write_query  # pyspark.sql.streaming.StreamingQuery

def op_groupby(df, column_names):
    df_aggregation = df.groupBy(column_names).count().sort(desc("count"))
    return df_aggregation


def op_windowed_groupby(df, window_duration, slide_duration):
    df_windowed_aggregation = df.groupBy(
        F.window(timeColumn=df.pickup_datetime, windowDuration=window_duration, slideDuration=slide_duration),
        df.PULocationID
    ).count()
    return df_windowed_aggregation


def prepare_df_to_kafka_sink(df, value_columns, key_column=None):
    columns = df.columns

    df = df.withColumn("value", F.concat_ws(', ', *value_columns))
    if key_column:
        df = df.withColumnRenamed(key_column, "key")
        df = df.withColumn("key", df.key.cast('string'))
    return df.select(['key', 'value'])


def sink_kafka(df, topic):
    write_query = df.writeStream \
        .format("kafka") \
        .option("kafka.bootstrap.servers", "************") \
        .option("topic", topic) \
        .option("checkpointLocation", "checkpoint") \
        .option("kafka.security.protocol","SASL_SSL") \
        .option("kafka.sasl.mechanism", "PLAIN") \
        .option("kafka.sasl.jaas.config","""org.apache.kafka.common.security.plain.PlainLoginModule required username="************" password="************";""") \
        .start()
    return write_query

# %%
sink_console(df_rides, output_mode='append')

df_trip_count_by_pickup_loc = op_groupby(df_rides, ['PULocationID'])
#df_trip_count_by_pickup_date_loc_id = op_windowed_groupby(df_rides, window_duration="10 minutes",slide_duration='5 minutes')

# write the output out to the console for debugging / testing
sink_console(df_trip_count_by_pickup_loc)
# write the output to the kafka topic
# Out:
# 23/03/14 11:30:55 WARN ResolveWriteToStream: Temporary checkpoint location created which is deleted normally when the query didn't fail: /tmp/temporary-5368c314-c5e0-4c19-af65-0c8dfc467bf1. If it's required to delete it under any circumstances, please set spark.sql.streaming.forceDeleteTempCheckpointLocation to true. Important to know deleting temp checkpoint folder is best effort.
# 23/03/14 11:30:55 WARN ResolveWriteToStream: spark.sql.adaptive.enabled is not supported in streaming DataFrames/Datasets and will be disabled.
# 23/03/14 11:30:55 WARN ResolveWriteToStream: Temporary checkpoint location created which is deleted normally when the query didn't fail: /tmp/temporary-14867b39-4625-4d40-abeb-8179324dcbe9. If it's required to delete it under any circumstances, please set spark.sql.streaming.forceDeleteTempCheckpointLocation to true. Important to know deleting temp checkpoint folder is best effort.
# 23/03/14 11:30:55 WARN ResolveWriteToStream: spark.sql.adaptive.enabled is not supported in streaming DataFrames/Datasets and will be disabled.
# -------------------------------------------
# Batch: 0
# -------------------------------------------
# [Stage 2:>                                                        (2 + 4) / 200]
# +-------------------------------------------+-------------------------------------------+-------------------+-------------------+-------------------+
# |pickup_datetime                            |dropOff_datetime                           |PULocationID       |DOLocationID       |texi_type          |
# +-------------------------------------------+-------------------------------------------+-------------------+-------------------+-------------------+
# |{"pickup_datetime": ["2019-01-04 18:01:15"]|"dropOff_datetime": ["2019-01-04 18:08:43"]|"PULocationID": 175|"DOLocationID": 16 |"texi_type": "FHV"}|
# |{"pickup_datetime": ["2019-01-09 09:09:08"]|"dropOff_datetime": ["2019-01-09 09:17:34"]|"PULocationID": 213|"DOLocationID": 60 |"texi_type": "FHV"}|
# |{"pickup_datetime": ["2019-01-02 22:24:22"]|"dropOff_datetime": ["2019-01-02 22:44:29"]|"PULocationID": 114|"DOLocationID": 142|"texi_type": "FHV"}|
# |{"pickup_datetime": ["2019-01-22 10:30:38"]|"dropOff_datetime": ["2019-01-22 10:36:00"]|"PULocationID": 174|"DOLocationID": 174|"texi_type": "FHV"}|
# |{"pickup_datetime": ["2019-01-28 20:36:17"]|"dropOff_datetime": ["2019-01-28 20:49:34"]|"PULocationID": 175|"DOLocationID": 122|"texi_type": "FHV"}|
# |{"pickup_datetime": ["2019-01-27 04:34:13"]|"dropOff_datetime": ["2019-01-27 04:36:55"]|"PULocationID": 116|"DOLocationID": 42 |"texi_type": "FHV"}|
# |{"pickup_datetime": ["2019-01-08 21:39:22"]|"dropOff_datetime": ["2019-01-08 21:59:30"]|"PULocationID": 161|"DOLocationID": 265|"texi_type": "FHV"}|
# |{"pickup_datetime": ["2019-01-15 23:39:18"]|"dropOff_datetime": ["2019-01-16 00:00:26"]|"PULocationID": 82 |"DOLocationID": 258|"texi_type": "FHV"}|
# |{"pickup_datetime": ["2019-01-20 05:52:06"]|"dropOff_datetime": ["2019-01-20 05:56:15"]|"PULocationID": 79 |"DOLocationID": 137|"texi_type": "FHV"}|
# |{"pickup_datetime": ["2019-01-31 05:40:15"]|"dropOff_datetime": ["2019-01-31 06:02:32"]|"PULocationID": 166|"DOLocationID": 140|"texi_type": "FHV"}|
# |{"pickup_datetime": ["2019-01-18 22:42:27"]|"dropOff_datetime": ["2019-01-18 22:51:26"]|"PULocationID": 56 |"DOLocationID": 82 |"texi_type": "FHV"}|
# |{"pickup_datetime": ["2019-01-04 16:50:30"]|"dropOff_datetime": ["2019-01-04 17:00:15"]|"PULocationID": 102|"DOLocationID": 196|"texi_type": "FHV"}|
# |{"pickup_datetime": ["2019-01
"texi_type": "GREEN"}|
# |{"pickup_datetime": ["2019-01-02 19:36:58"]|"dropOff_datetime": ["2019-01-02 19:39:31"]|"PULocationID": 7  |"DOLocationID": 179|"texi_type": "GREEN"}|
# |{"pickup_datetime": ["2019-01-02 19:01:06"]|"dropOff_datetime": ["2019-01-02 19:43:06"]|"PULocationID": 37 |"DOLocationID": 235|"texi_type": "GREEN"}|
# |{"pickup_datetime": ["2019-01-02 19:24:35"]|"dropOff_datetime": ["2019-01-02 19:30:47"]|"PULocationID": 43 |"DOLocationID": 236|"texi_type": "GREEN"}|
# |{"pickup_datetime": ["2019-01-02 20:02:29"]|"dropOff_datetime": ["2019-01-02 20:13:27"]|"PULocationID": 66 |"DOLocationID": 79 |"texi_type": "GREEN"}|
# |{"pickup_datetime": ["2019-01-02 19:53:20"]|"dropOff_datetime": ["2019-01-02 20:15:19"]|"PULocationID": 101|"DOLocationID": 216|"texi_type": "GREEN"}|
# +-------------------------------------------+-------------------------------------------+-------------------+-------------------+---------------------+
# only showing top 20 rows
#
# 23/03/14 11:31:17 WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 10030 milliseconds
# [Stage 5:====>           (54 + 4) / 200][Stage 7:>                  (0 + 0) / 4]

# %%
df_trip_count_messages = prepare_df_to_kafka_sink(df=df_rides,
                                                  value_columns=['texi_type','pickup_datetime','dropOff_datetime','PULocationID','DOLocationID'], key_column='PULocationID')
kafka_sink_query = sink_kafka(df=df_trip_count_messages, topic="rides_all")
# Out:
# [Stage 5:=====>          (67 + 4) / 200][Stage 7:>                  (0 + 0) / 4]
# 23/03/14 11:31:20 WARN ResolveWriteToStream: spark.sql.adaptive.enabled is not supported in streaming DataFrames/Datasets and will be disabled.
# -------------------------------------------
# Batch: 2
# -------------------------------------------
# +-------------------------------------------+-------------------------------------------+-------------------+-------------------+---------------------+
# |pickup_datetime                            |dropOff_datetime                           |PULocationID       |DOLocationID       |texi_type            |
# +-------------------------------------------+-------------------------------------------+-------------------+-------------------+---------------------+
# |{"pickup_datetime": ["2019-01-02 20:03:01"]|"dropOff_datetime": ["2019-01-02 20:14:00"]|"PULocationID": 74 |"DOLocationID": 263|"texi_type": "GREEN"}|
# |{"pickup_datetime": ["2019-01-02 19:12:45"]|"dropOff_datetime": ["2019-01-02 19:17:33"]|"PULocationID": 129|"DOLocationID": 173|"texi_type": "GREEN"}|
# |{"pickup_datetime": ["2019-01-02 19:08:41"]|"dropOff_datetime": ["2019-01-02 19:46:00"]|"PULocationID": 217|"DOLocationID": 26 |"texi_type": "GREEN"}|
# |{"pickup_datetime": ["2019-01-02 19:56:29"]|"dropOff_datetime": ["2019-01-02 20:03:22"]|"PULocationID": 75 |"DOLocationID": 24 |"texi_type": "GREEN"}|
# |{"pickup_datetime": ["2019-01-02 19:48:15"]|"dropOff_datetime": ["2019-01-02 19:59:11"]|"PULocationID": 260|"DOLocationID": 223|"texi_type": "GREEN"}|
# |{"pickup_datetime": ["2019-01-02 19:25:38"]|"dropOff_datetime": ["2019-01-02 19:36:40"]|"PULocationID": 226|"DOLocationID": 223|"texi_type": "GREEN"}|
# |{"pickup_datetime": ["2019-01-02 19:22:21"]|"dropOff_datetime": ["2019-01-02 19:29:01"]|"PULocationID": 42 |"DOLocationID": 119|"texi_type": "GREEN"}|
# |{"pickup_datetime": ["2019-01-02 20:00:56"]|"dropOff_datetime": ["2019-01-02 20:13:45"]|"PULocationID": 7  |"DOLocationID": 260|"texi_type": "GREEN"}|
# |{"pickup_datetime": ["2019-01-02 19:28:42"]|"dropOff_datetime": ["2019-01-02 19:38:41"]|"PULocationID": 223|"DOLocationID": 138|"texi_type": "GREEN"}|
# |{"pickup_datetime": ["2019-01-02 19:37:29"]|"dropOff_datetime": ["2019-01-02 20:01:53"]|"PULocationID": 166|"DOLocationID": 146|"texi_type": "GREEN"}|
# |{"pickup_datetime": ["2019-01-02 19:33:37"]|"dropOff_datetime": ["2019-01-02 19:56:12"]|"PULocationID": 208|"DOLocationID": 18 |"texi_type": "GREEN"}|
# |{"pickup_datetime": ["2019-01-02 19:21:50"]|"dropOff_datetime": ["2019-01-02 19:33:04"]|"PULocationID": 134|"DOLocationID": 216|"texi_type": "GREEN"}|
# |{"pickup_datetime": ["2019-01-02 19:21:47"]|"dropOff_datetime": ["2019-01-02 19:28:30"]|"PULocationID": 223|"DOLocationID": 223|"texi_type": "GREEN"}|
# |{"pickup_datetime": ["2019-01-02 19:51:22"]|"dropOff_datetime": ["2019-01-02 19:55:33"]|"PULocationID": 223|"DOLocationID": 223|"texi_type": "GREEN"}|
# |{"pickup_datetime": ["2019-01-02 19:48:11"]|"dropOff_datetime": ["2019-01-02 19:55:42"]|"PULocationID": 75 |"DOLocationID": 151|"texi_type": "GREEN"}|
# |{"pickup_datetime": ["2019-01-02 19
WARN ProcessingTimeExecutor: Current batch is falling behind. The trigger interval is 5000 milliseconds, but spent 10045 milliseconds
# -------------------------------------------
# Batch: 66
# -------------------------------------------
# +-------------------------------------------+-------------------------------------------+-------------------+-------------------+---------------------+
# |pickup_datetime                            |dropOff_datetime                           |PULocationID       |DOLocationID       |texi_type            |
# +-------------------------------------------+-------------------------------------------+-------------------+-------------------+---------------------+
# |{"pickup_datetime": ["2019-01-03 08:55:43"]|"dropOff_datetime": ["2019-01-03 08:57:17"]|"PULocationID": 28 |"DOLocationID": 134|"texi_type": "GREEN"}|
# |{"pickup_datetime": ["2019-01-03 08:11:53"]|"dropOff_datetime": ["2019-01-03 08:58:59"]|"PULocationID": 220|"DOLocationID": 231|"texi_type": "GREEN"}|
# |{"pickup_datetime": ["2019-01-03 08:20:02"]|"dropOff_datetime": ["2019-01-03 08:42:27"]|"PULocationID": 195|"DOLocationID": 97 |"texi_type": "GREEN"}|
# |{"pickup_datetime": ["2019-01-03 08:09:05"]|"dropOff_datetime": ["2019-01-03 08:15:51"]|"PULocationID": 41 |"DOLocationID": 42 |"texi_type": "GREEN"}|
# |{"pickup_datetime": ["2019-01-03 08:55:28"]|"dropOff_datetime": ["2019-01-03 08:58:48"]|"PULocationID": 41 |"DOLocationID": 42 |"texi_type": "GREEN"}|
# |{"pickup_datetime": ["2019-01-03 08:14:03"]|"dropOff_datetime": ["2019-01-03 08:25:43"]|"PULocationID": 74 |"DOLocationID": 75 |"texi_type": "GREEN"}|
# |{"pickup_datetime": ["2019-01-03 08:58:07"]|"dropOff_datetime": ["2019-01-03 09:50:14"]|"PULocationID": 55 |"DOLocationID": 137|"texi_type": "GREEN"}|
# |{"pickup_datetime": ["2019-01-03 08:10:59"]|"dropOff_datetime": ["2019-01-03 08:16:22"]|"PULocationID": 166|"DOLocationID": 41 |"texi_type": "GREEN"}|
# |{"pickup_datetime": ["2019-01-03 08:49:48"]|"dropOff_datetime": ["2019-01-03 09:09:14"]|"PULocationID": 75 |"DOLocationID": 142|"texi_type": "GREEN"}|
# |{"pickup_datetime": ["2019-01-03 08:18:51"]|"dropOff_datetime": ["2019-01-03 08:44:21"]|"PULocationID": 35 |"DOLocationID": 155|"texi_type": "GREEN"}|
# |{"pickup_datetime": ["2019-01-03 08:49:10"]|"dropOff_datetime": ["2019-01-03 09:24:35"]|"PULocationID": 258|"DOLocationID": 14 |"texi_type": "GREEN"}|
# |{"pickup_datetime": ["2019-01-03 08:12:57"]|"dropOff_datetime": ["2019-01-03 08:16:03"]|"PULocationID": 182|"DOLocationID": 212|"texi_type": "GREEN"}|
# |{"pickup_datetime": ["2019-01-03 08:17:09"]|"dropOff_datetime": ["2019-01-03 08:39:11"]|"PULocationID": 195|"DOLocationID": 108|"texi_type": "GREEN"}|
# |{"pickup_datetime": ["2019-01-03 08:57:24"]|"dropOff_datetime": ["2019-01-03 09:26:38"]|"PULocationID": 11 |"DOLocationID": 76 |"texi_type": "GREEN"}|
# |{"pickup_datetime": ["2019-01-03 08:01:52"]|"dropOff_datetime": ["2019-01-03 08:05:20"]|"PULocationID": 42 |"DOLocationID": 42 |"texi_type": "GREEN"}|
# |{"pickup_datetime": ["2019-01-03 08:31:54"]|"dropOff_datetime": ["2019-01-03 08:40:36"]|"PULocationID": 74 |"DOLocationID": 41 |"texi_type": "GREEN"}|
# |{"pickup_datetime": ["2019-01-03 08:59:54"]|"dropOff_datetime": ["2019-01-03 09:05:50"]|"PULocationID": 74 |"DOLocationID": 43 |"texi_type": "GREEN"}|
# |{"pickup_datetime": ["2019-01-03 08:56:40"]|"dropOff_datetime": ["2019-01-03 09:26:32"]|"PULocationID": 40 |"DOLocationID": 233|"texi_type": "GREEN"}|
# |{"pickup_datetime": ["2019-01-03 08:46:26"]|"dropOff_datetime": ["2019-01-03 09:09:30"]|"PULocationID": 41 |"DOLocationID": 162|"texi_type": "GREEN"}|
# |{"pickup_datetime": ["2019-01-03 08:38:26"]|"dropOff_datetime": ["2019-01-03 08:46:29"]|"PULocationID": 74 |"DOLocationID": 75 |"texi_type": "GREEN"}|
# +-------------------------------------------+-------------------------------------------+-------------------+-------------------+---------------------+
# only showing top 20 rows
# [Stage 316:========>    (129 + 4) / 200][Stage 318:>                (0 + 0) / 2]
