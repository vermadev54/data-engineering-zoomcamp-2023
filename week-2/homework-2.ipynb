# %% [markdown]
# ## Q1 solution

# %% [markdown]
# ![Q1.png](attachment:Q1.png)

# %% [markdown]
# ## Q2 Solution

# %%
# prefect deployment build etl_web_to_gcs.py:etl_web_to_gcs --cron "0 5 1 * *" -n "web_to_gcs_cron_q2"

# %% [markdown]
# ![Q2.png](attachment:Q2.png)

# %% [markdown]
# ## Q3 solution

# %% [markdown]
# ![Q3-1.png](attachment:Q3-1.png)

# %% [markdown]
# ![Q3-2.png](attachment:Q3-2.png)

# %% [markdown]
# ## Q4 solution

# %% [markdown]
# ![Q4.png](attachment:Q4.png)

# %% [markdown]
# ![Q4ref.png](attachment:Q4ref.png)

# %% [markdown]
# ## Q5 solution

# %% [markdown]
# ![Q5-1.png](attachment:Q5-1.png)

# %% [markdown]
# ![Q5-2.png](attachment:Q5-2.png)

# %% [markdown]
# ## Q6 solution

# %% [markdown]
# ![Q6.png](attachment:Q6.png)
